# %%
import pandas as pd

#for time series we are going to use a new library called statsmodel
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
Product_mary2 = pd.read_csv(r'C:\Users\Tracy\Downloads\Canna_project\g5mj-5pg3.csv')

Product_mary2
# Out:
#       CCCLastUpdated  RecordNo    SaleDate   ProductCategoryName  \
# 0         11/13/2023         1   11/5/2018      Infused (edible)
# 1         11/13/2023         2  11/20/2018                  Buds
# 2         11/13/2023         2  11/20/2018  Infused (non-edible)
# 3         11/13/2023         2  11/20/2018      Infused (edible)
# 4         11/13/2023         2  11/20/2018    Concentrate (Each)
# ...              ...       ...         ...                   ...
# 21944     11/13/2023     21936  11/12/2023          Vape Product
# 21945     11/13/2023     21936  11/12/2023           Concentrate
# 21946     11/13/2023     21936  11/12/2023                  Buds
# 21947     11/13/2023     21936  11/12/2023           Suppository
# 21948     11/13/2023     21936  11/12/2023           Concentrate
#
#       UnitOfMeasureName  CountBasedTotal  DollarCountBasedTotal  \
# 0                  Each                2                  60.00
# 1                 Grams                0                   0.00
# 2                  Each                3                  89.74
# 3                  Each               61                1381.90
# 4                  Each              101                4931.18
# ...                 ...              ...                    ...
# 21944              Each             2723               73417.00
# 21945             Grams                0                   0.00
# 21946             Grams                0                   0.00
# 21947              Each                1                  20.00
# 21948        Milligrams                0                   0.00
#
#        WeightBasedTotal  DollarWeightBasedTotal  Quantity  TotalPrice
# 0                  0.00                    0.00      2.00       60.00
# 1                441.51                 5159.59    441.51     5159.59
# 2                  0.00                    0.00      3.00       89.74
# 3                  0.00                    0.00     61.00     1381.90
# 4                  0.00                    0.00    101.00     4931.18
# ...                 ...                     ...       ...         ...
# 21944              0.00                    0.00   2723.00    73417.00
# 21945             54.00                 1536.32     54.00     1536.32
# 21946          42151.64               199772.21  42151.64   199772.21
# 21947              0.00                    0.00      1.00       20.00
# 21948           1000.00                   45.00   1000.00       45.00
#
# [21949 rows x 11 columns]

# %%
Product_mary = pd.read_csv(r'C:\Users\Tracy\Downloads\Canna_project\dt9b-i6ds.csv')

Product_mary
# Out:
#       CCCLastUpdated  RecordNo    SaleDate ProductCategoryName  \
# 0         11/13/2023         1   11/5/2018    Infused (edible)
# 1         11/13/2023         2   11/6/2018    Infused (edible)
# 2         11/13/2023         3  11/19/2018                Buds
# 3         11/13/2023         3  11/19/2018  Concentrate (Each)
# 4         11/13/2023         5  11/20/2018  Concentrate (Each)
# ...              ...       ...         ...                 ...
# 23891     11/13/2023     23878  11/12/2023         Suppository
# 23892     11/13/2023     23878  11/12/2023                Kief
# 23893     11/13/2023     23878  11/12/2023                Buds
# 23894     11/13/2023     23878  11/12/2023     Immature Plants
# 23895     11/13/2023     23878  11/12/2023    Infused (edible)
#
#       UnitOfMeasureName  CountBasedTotal  DollarCountBasedTotal  \
# 0                  Each                2                  60.00
# 1                  Each                2                  57.00
# 2                 Grams                0                   0.00
# 3                  Each                0                   0.00
# 4                  Each             3031              163585.03
# ...                 ...              ...                    ...
# 23891              Each                6                 163.66
# 23892             Grams                0                   0.00
# 23893            Pounds                0                   0.00
# 23894              Each               12                 515.00
# 23895              Each            24290              450356.86
#
#        WeightBasedTotal  DollarWeightBasedTotal  Quantity  TotalPrice
# 0                  0.00                    0.00      2.00       60.00
# 1                  0.00                    0.00      2.00       57.00
# 2                  0.00                    0.00      0.00        0.00
# 3                  0.00                    0.00      0.00        0.00
# 4                  0.00                    0.00   3031.00   163585.03
# ...                 ...                     ...       ...         ...
# 23891              0.00                    0.00      6.00      163.66
# 23892             91.00                 2010.73     91.00     2010.73
# 23893              0.02                   20.11      0.02       20.11
# 23894              0.00                    0.00     12.00      515.00
# 23895              0.00                    0.00  24498.10   450356.86
#
# [23896 rows x 11 columns]

# %%
Product_Sales = pd.concat((Product_mary,Product_mary2),axis = 0)

# %%
Product_Sales
# Out:
#       CCCLastUpdated  RecordNo    SaleDate ProductCategoryName  \
# 0         11/13/2023         1   11/5/2018    Infused (edible)
# 1         11/13/2023         2   11/6/2018    Infused (edible)
# 2         11/13/2023         3  11/19/2018                Buds
# 3         11/13/2023         3  11/19/2018  Concentrate (Each)
# 4         11/13/2023         5  11/20/2018  Concentrate (Each)
# ...              ...       ...         ...                 ...
# 21944     11/13/2023     21936  11/12/2023        Vape Product
# 21945     11/13/2023     21936  11/12/2023         Concentrate
# 21946     11/13/2023     21936  11/12/2023                Buds
# 21947     11/13/2023     21936  11/12/2023         Suppository
# 21948     11/13/2023     21936  11/12/2023         Concentrate
#
#       UnitOfMeasureName  CountBasedTotal  DollarCountBasedTotal  \
# 0                  Each                2                  60.00
# 1                  Each                2                  57.00
# 2                 Grams                0                   0.00
# 3                  Each                0                   0.00
# 4                  Each             3031              163585.03
# ...                 ...              ...                    ...
# 21944              Each             2723               73417.00
# 21945             Grams                0                   0.00
# 21946             Grams                0                   0.00
# 21947              Each                1                  20.00
# 21948        Milligrams                0                   0.00
#
#        WeightBasedTotal  DollarWeightBasedTotal  Quantity  TotalPrice
# 0                  0.00                    0.00      2.00       60.00
# 1                  0.00                    0.00      2.00       57.00
# 2                  0.00                    0.00      0.00        0.00
# 3                  0.00                    0.00      0.00        0.00
# 4                  0.00                    0.00   3031.00   163585.03
# ...                 ...                     ...       ...         ...
# 21944              0.00                    0.00   2723.00    73417.00
# 21945             54.00                 1536.32     54.00     1536.32
# 21946          42151.64               199772.21  42151.64   199772.21
# 21947              0.00                    0.00      1.00       20.00
# 21948           1000.00                   45.00   1000.00       45.00
#
# [45845 rows x 11 columns]

# %%
cols = []

for i in range(len(Product_Sales.columns)) :
    cols.append(Product_Sales.columns[i].lower())
Product_Sales.columns = cols

Product_Sales
# Out:
#       ccclastupdated  recordno    saledate productcategoryname  \
# 0         11/13/2023         1   11/5/2018    Infused (edible)
# 1         11/13/2023         2   11/6/2018    Infused (edible)
# 2         11/13/2023         3  11/19/2018                Buds
# 3         11/13/2023         3  11/19/2018  Concentrate (Each)
# 4         11/13/2023         5  11/20/2018  Concentrate (Each)
# ...              ...       ...         ...                 ...
# 21944     11/13/2023     21936  11/12/2023        Vape Product
# 21945     11/13/2023     21936  11/12/2023         Concentrate
# 21946     11/13/2023     21936  11/12/2023                Buds
# 21947     11/13/2023     21936  11/12/2023         Suppository
# 21948     11/13/2023     21936  11/12/2023         Concentrate
#
#       unitofmeasurename  countbasedtotal  dollarcountbasedtotal  \
# 0                  Each                2                  60.00
# 1                  Each                2                  57.00
# 2                 Grams                0                   0.00
# 3                  Each                0                   0.00
# 4                  Each             3031              163585.03
# ...                 ...              ...                    ...
# 21944              Each             2723               73417.00
# 21945             Grams                0                   0.00
# 21946             Grams                0                   0.00
# 21947              Each                1                  20.00
# 21948        Milligrams                0                   0.00
#
#        weightbasedtotal  dollarweightbasedtotal  quantity  totalprice
# 0                  0.00                    0.00      2.00       60.00
# 1                  0.00                    0.00      2.00       57.00
# 2                  0.00                    0.00      0.00        0.00
# 3                  0.00                    0.00      0.00        0.00
# 4                  0.00                    0.00   3031.00   163585.03
# ...                 ...                     ...       ...         ...
# 21944              0.00                    0.00   2723.00    73417.00
# 21945             54.00                 1536.32     54.00     1536.32
# 21946          42151.64               199772.21  42151.64   199772.21
# 21947              0.00                    0.00      1.00       20.00
# 21948           1000.00                   45.00   1000.00       45.00
#
# [45845 rows x 11 columns]

# %%
Product_Sales.drop(['ccclastupdated'],axis=1 )
# Out:
#        recordno    saledate productcategoryname unitofmeasurename  \
# 0             1   11/5/2018    Infused (edible)              Each
# 1             2   11/6/2018    Infused (edible)              Each
# 2             3  11/19/2018                Buds             Grams
# 3             3  11/19/2018  Concentrate (Each)              Each
# 4             5  11/20/2018  Concentrate (Each)              Each
# ...         ...         ...                 ...               ...
# 21944     21936  11/12/2023        Vape Product              Each
# 21945     21936  11/12/2023         Concentrate             Grams
# 21946     21936  11/12/2023                Buds             Grams
# 21947     21936  11/12/2023         Suppository              Each
# 21948     21936  11/12/2023         Concentrate        Milligrams
#
#        countbasedtotal  dollarcountbasedtotal  weightbasedtotal  \
# 0                    2                  60.00              0.00
# 1                    2                  57.00              0.00
# 2                    0                   0.00              0.00
# 3                    0                   0.00              0.00
# 4                 3031              163585.03              0.00
# ...                ...                    ...               ...
# 21944             2723               73417.00              0.00
# 21945                0                   0.00             54.00
# 21946                0                   0.00          42151.64
# 21947                1                  20.00              0.00
# 21948                0                   0.00           1000.00
#
#        dollarweightbasedtotal  quantity  totalprice
# 0                        0.00      2.00       60.00
# 1                        0.00      2.00       57.00
# 2                        0.00      0.00        0.00
# 3                        0.00      0.00        0.00
# 4                        0.00   3031.00   163585.03
# ...                       ...       ...         ...
# 21944                    0.00   2723.00    73417.00
# 21945                 1536.32     54.00     1536.32
# 21946               199772.21  42151.64   199772.21
# 21947                    0.00      1.00       20.00
# 21948                   45.00   1000.00       45.00
#
# [45845 rows x 10 columns]

# %%
# Year 

# WIll make a new dataframe by calculiong the Number of new open license per year 

Product_Sales['saledate'] = pd.to_datetime(Product_Sales['saledate'])


# first we will convert to  date and time lic start date .


# Canna_retail_by_Year = count(

# %%
Product_Sales.dtypes
# Out:
# ccclastupdated                    object
# recordno                           int64
# saledate                  datetime64[ns]
# productcategoryname               object
# unitofmeasurename                 object
# countbasedtotal                    int64
# dollarcountbasedtotal            float64
# weightbasedtotal                 float64
# dollarweightbasedtotal           float64
# quantity                         float64
# totalprice                       float64
# dtype: object

# %%
#since this is a TS, we make the date into the index
Product_Sales.index = pd.DatetimeIndex(Product_Sales['saledate'])
Product_Sales
# Out:
#            ccclastupdated  recordno   saledate productcategoryname  \
# saledate
# 2018-11-05     11/13/2023         1 2018-11-05    Infused (edible)
# 2018-11-06     11/13/2023         2 2018-11-06    Infused (edible)
# 2018-11-19     11/13/2023         3 2018-11-19                Buds
# 2018-11-19     11/13/2023         3 2018-11-19  Concentrate (Each)
# 2018-11-20     11/13/2023         5 2018-11-20  Concentrate (Each)
# ...                   ...       ...        ...                 ...
# 2023-11-12     11/13/2023     21936 2023-11-12        Vape Product
# 2023-11-12     11/13/2023     21936 2023-11-12         Concentrate
# 2023-11-12     11/13/2023     21936 2023-11-12                Buds
# 2023-11-12     11/13/2023     21936 2023-11-12         Suppository
# 2023-11-12     11/13/2023     21936 2023-11-12         Concentrate
#
#            unitofmeasurename  countbasedtotal  dollarcountbasedtotal  \
# saledate
# 2018-11-05              Each                2                  60.00
# 2018-11-06              Each                2                  57.00
# 2018-11-19             Grams                0                   0.00
# 2018-11-19              Each                0                   0.00
# 2018-11-20              Each             3031              163585.03
# ...                      ...              ...                    ...
# 2023-11-12              Each             2723               73417.00
# 2023-11-12             Grams                0                   0.00
# 2023-11-12             Grams                0                   0.00
# 2023-11-12              Each                1                  20.00
# 2023-11-12        Milligrams                0                   0.00
#
#             weightbasedtotal  dollarweightbasedtotal  quantity  totalprice
# saledate
# 2018-11-05              0.00                    0.00      2.00       60.00
# 2018-11-06              0.00                    0.00      2.00       57.00
# 2018-11-19              0.00                    0.00      0.00        0.00
# 2018-11-19              0.00                    0.00      0.00        0.00
# 2018-11-20              0.00                    0.00   3031.00   163585.03
# ...                      ...                     ...       ...         ...
# 2023-11-12              0.00                    0.00   2723.00    73417.00
# 2023-11-12             54.00                 1536.32     54.00     1536.32
# 2023-11-12          42151.64               199772.21  42151.64   199772.21
# 2023-11-12              0.00                    0.00      1.00       20.00
# 2023-11-12           1000.00                   45.00   1000.00       45.00
#
# [45845 rows x 11 columns]

# %%
# seasonal decompose tries to check for multiple "potential" seasonal periods.
# in this case we have a monthly cycle 
decomp = sm.tsa.seasonal_decompose(Product_Sales['totalprice'],period=365)
decomp.plot()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

# Assuming Product_Sales is your DataFrame with 'saledate' as the datetime index
Product_Sales['saledate'] = pd.to_datetime(Product_Sales['saledate'])
Product_Sales.index = pd.DatetimeIndex(Product_Sales['saledate'])

# Perform seasonal decomposition
decomp = sm.tsa.seasonal_decompose(Product_Sales['totalprice'], period=1825)  # Assuming a monthly cycle

# Plot the decomposed components
trend = decomp.trend
seasonal = decomp.seasonal
residual = decomp.resid

plt.figure(figsize=(12, 8))

plt.subplot(411)
plt.plot(Product_Sales['totalprice'], label='Original')
plt.legend(loc='upper left')

plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='upper left')

plt.subplot(413)
plt.plot(seasonal, label='Seasonal')
plt.legend(loc='upper left')

plt.subplot(414)
plt.plot(residual, label='Residual')
plt.legend(loc='upper left')

plt.tight_layout()
plt.show()

# %%
# we want to check if there is a relation between consecutive datapoints. 
# this is a requisite for an AR model
plt.scatter(Product_Sales['totalprice'][:-1],Product_Sales['totalprice'][1:],s=0.1)
plt.show()


"""Random Scatter: If the lag plot shows a random scatter of points, it suggests that the total price of weed sales on a particular day is not significantly correlated with the total price on the previous day. This could mean that each day's sales are independent of the previous day's sales.
No Clear Pattern: If there's no clear pattern in the lag plot, it could suggest that there is little to no autocorrelation between consecutive days' total sales."""
# Out:
# "Random Scatter: If the lag plot shows a random scatter of points, it suggests that the total price of weed sales on a particular day is not significantly correlated with the total price on the previous day. This could mean that each day's sales are independent of the previous day's sales.\nNo Clear Pattern: If there's no clear pattern in the lag plot, it could suggest that there is little to no autocorrelation between consecutive days' total sales."

# %%
# Check if the index is a datetime index
is_datetime_index = pd.api.types.is_datetime64_any_dtype(Product_Sales.index)

# Display the result
print("Is datetime index:", is_datetime_index)
# Out:
# Is datetime index: True

# %%
# Assuming your DataFrame is named Product_Sales
Product_Sales['saledate'] = pd.to_datetime(Product_Sales['saledate'])
Product_Sales.index = pd.DatetimeIndex(Product_Sales['saledate'])

# Group by day and sum the 'totalprice'
daily_sales = Product_Sales.resample('D').sum(numeric_only=True)

# Display the resulting DataFrame
print(daily_sales)
# Out:
#             recordno  countbasedtotal  dollarcountbasedtotal  \
# saledate
# 2018-11-05         2                4                 120.00
# 2018-11-06         2                2                  57.00
# 2018-11-07         0                0                   0.00
# 2018-11-08         0                0                   0.00
# 2018-11-09         0                0                   0.00
# ...              ...              ...                    ...
# 2023-11-08    756711            69164             1665549.47
# 2023-11-09    711541            78647             1874344.36
# 2023-11-10    757776           101058             2398632.54
# 2023-11-11    714479            90972             2154327.15
# 2023-11-12    760786            63920             1570499.56
#
#             weightbasedtotal  dollarweightbasedtotal   quantity  totalprice
# saledate
# 2018-11-05              0.00                    0.00       4.00      120.00
# 2018-11-06              0.00                    0.00       2.00       57.00
# 2018-11-07              0.00                    0.00       0.00        0.00
# 2018-11-08              0.00                    0.00       0.00        0.00
# 2018-11-09              0.00                    0.00       0.00        0.00
# ...                      ...                     ...        ...         ...
# 2023-11-08         451068.23              2741836.29  520451.33  4407385.76
# 2023-11-09         507681.95              3146880.11  586328.95  5021224.47
# 2023-11-10         642651.18              3934261.18  743709.18  6332893.72
# 2023-11-11         543568.90              3338630.93  634540.90  5492958.08
# 2023-11-12         424694.71              2581819.29  488822.81  4152318.85
#
# [1834 rows x 7 columns]

# %%
from statsmodels.tsa.ar_model import AutoReg

# Assuming your DataFrame has a datetime index
start_date = '2018-11-05'
end_date = '2023-01-01'  # Adjust the end date as needed

# Extract rows for the first four years
subset_data = len(daily_sales[start_date:end_date])

# Display the subset of data
print(subset_data)
# Out:
# 1519

# %%
train = daily_sales['totalprice'][:subset_data] 

test = daily_sales['totalprice'][subset_data:]

# %%
from statsmodels.tsa.arima.model import ARIMA

# Assuming daily_sales is your time series DataFrame
model = ARIMA(daily_sales['totalprice'], order=(0, 0, 12))

# Train the model
model_fit = model.fit()

# Make prediction

predictions = model_fit.predict(start = len(daily_sales['totalprice'])-10, end = len(daily_sales['totalprice'])-1)
print(predictions)
# Out:
# saledate
# 2023-11-03    5.170408e+06
# 2023-11-04    5.573139e+06
# 2023-11-05    4.770221e+06
# 2023-11-06    4.241724e+06
# 2023-11-07    4.003786e+06
# 2023-11-08    3.951031e+06
# 2023-11-09    4.472562e+06
# 2023-11-10    5.151662e+06
# 2023-11-11    5.360985e+06
# 2023-11-12    4.752343e+06
# Freq: D, Name: predicted_mean, dtype: float64

# %%
# and visually
plt.plot(test)
plt.plot(predictions)
plt.show()

# %%
from statsmodels.tsa.arima.model import ARIMA

#create model
model = ARIMA(daily_sales['totalprice'], order=(2,0 ,12))
# train model
model_fit = model.fit()
# make prediction
predictions = model_fit.predict(start = len(daily_sales['totalprice'])-10, end = len(daily_sales['totalprice'])-1)
predictions
# Out:
# d:\Anaconda\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# saledate
# 2023-11-03    5.356196e+06
# 2023-11-04    5.343968e+06
# 2023-11-05    4.476456e+06
# 2023-11-06    4.271011e+06
# 2023-11-07    4.582804e+06
# 2023-11-08    4.749317e+06
# 2023-11-09    4.913287e+06
# 2023-11-10    5.398305e+06
# 2023-11-11    5.324962e+06
# 2023-11-12    4.615972e+06
# Freq: D, Name: predicted_mean, dtype: float64

# %%
daily_sales
# Out:
#             recordno  countbasedtotal  dollarcountbasedtotal  \
# saledate
# 2018-11-05         2                4                 120.00
# 2018-11-06         2                2                  57.00
# 2018-11-07         0                0                   0.00
# 2018-11-08         0                0                   0.00
# 2018-11-09         0                0                   0.00
# ...              ...              ...                    ...
# 2023-11-08    756711            69164             1665549.47
# 2023-11-09    711541            78647             1874344.36
# 2023-11-10    757776           101058             2398632.54
# 2023-11-11    714479            90972             2154327.15
# 2023-11-12    760786            63920             1570499.56
#
#             weightbasedtotal  dollarweightbasedtotal   quantity  totalprice
# saledate
# 2018-11-05              0.00                    0.00       4.00      120.00
# 2018-11-06              0.00                    0.00       2.00       57.00
# 2018-11-07              0.00                    0.00       0.00        0.00
# 2018-11-08              0.00                    0.00       0.00        0.00
# 2018-11-09              0.00                    0.00       0.00        0.00
# ...                      ...                     ...        ...         ...
# 2023-11-08         451068.23              2741836.29  520451.33  4407385.76
# 2023-11-09         507681.95              3146880.11  586328.95  5021224.47
# 2023-11-10         642651.18              3934261.18  743709.18  6332893.72
# 2023-11-11         543568.90              3338630.93  634540.90  5492958.08
# 2023-11-12         424694.71              2581819.29  488822.81  4152318.85
#
# [1834 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# Assuming count_per_year_df is your time series DataFrame with 'Month' as the index
# Make sure the DataFrame has 'count' as the target variable

# Fit the ARIMA model
# Here, order=(p, d, q), where p, d, and q are the AR order, differencing order, and MA order, respectively.
order = (1, 3, 12)  # Adjust order based on your analysis
model = ARIMA(train, order=order)
results = model.fit()

# Forecast future values
forecast_steps = len(test)
forecast = results.get_forecast(steps=forecast_steps)

# Get confidence intervals
conf_int = forecast.conf_int()

# Plot the results
plt.figure(figsize=(12, 6))
plt.plot(train, label='Train')
plt.plot(test, label='Test')
plt.plot(forecast.predicted_mean, label='Forecast', color='red')
plt.fill_between(conf_int.index, conf_int.iloc[:, 0], conf_int.iloc[:, 1], color='red', alpha=0.2)
plt.title('ARIMA Forecast')
plt.legend()
plt.show()
# Out:
# d:\Anaconda\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'

# %%
train
# Out:
# saledate
# 2018-11-05        120.00
# 2018-11-06         57.00
# 2018-11-07          0.00
# 2018-11-08          0.00
# 2018-11-09          0.00
#                  ...
# 2022-12-28    4996084.89
# 2022-12-29    5459301.51
# 2022-12-30    6911760.57
# 2022-12-31    5996525.15
# 2023-01-01    2501430.72
# Freq: D, Name: totalprice, Length: 1519, dtype: float64

# %%
# Assuming count_per_year_df is your time series DataFrame with 'Month' as the index
# Make sure the DataFrame has 'count' as the target variable

# Split the data into training and testing sets


# Fit the ARIMA model
# Here, order=(p, d, q), where p, d, and q are the AR order, differencing order, and MA order, respectively.
order = (1, 3, 12)  # Adjust order based on your analysis
model = ARIMA(train, order=order)
results = model.fit()

# Forecast future values
forecast_steps = len(test)
forecast = results.get_forecast(steps=forecast_steps)

# Get confidence intervals
conf_int = forecast.conf_int()

# Plot the results
plt.figure(figsize=(12, 6))
plt.plot(train, label='Train')
plt.plot(test, label='Test')
plt.plot(forecast.predicted_mean, label='Forecast', color='red')
plt.fill_between(conf_int.index, conf_int.iloc[:, 0], conf_int.iloc[:, 1], color='red', alpha=0.2)
plt.title('ARIMA Forecast')
plt.legend()
plt.show()
# Out:
# d:\Anaconda\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'

# %%
# Assuming forecast_steps is the number of steps for the next year
forecast_steps = 365
forecast = results.get_forecast(steps=forecast_steps)

# %%
daily_sales
# Out:
#             recordno  countbasedtotal  dollarcountbasedtotal  \
# saledate
# 2018-11-05         2                4                 120.00
# 2018-11-06         2                2                  57.00
# 2018-11-07         0                0                   0.00
# 2018-11-08         0                0                   0.00
# 2018-11-09         0                0                   0.00
# ...              ...              ...                    ...
# 2023-11-08    756711            69164             1665549.47
# 2023-11-09    711541            78647             1874344.36
# 2023-11-10    757776           101058             2398632.54
# 2023-11-11    714479            90972             2154327.15
# 2023-11-12    760786            63920             1570499.56
#
#             weightbasedtotal  dollarweightbasedtotal   quantity  totalprice
# saledate
# 2018-11-05              0.00                    0.00       4.00      120.00
# 2018-11-06              0.00                    0.00       2.00       57.00
# 2018-11-07              0.00                    0.00       0.00        0.00
# 2018-11-08              0.00                    0.00       0.00        0.00
# 2018-11-09              0.00                    0.00       0.00        0.00
# ...                      ...                     ...        ...         ...
# 2023-11-08         451068.23              2741836.29  520451.33  4407385.76
# 2023-11-09         507681.95              3146880.11  586328.95  5021224.47
# 2023-11-10         642651.18              3934261.18  743709.18  6332893.72
# 2023-11-11         543568.90              3338630.93  634540.90  5492958.08
# 2023-11-12         424694.71              2581819.29  488822.81  4152318.85
#
# [1834 rows x 7 columns]

# %%
# Add one year to the 'saledate' column
daily_sales.index = daily_sales.index + pd.DateOffset(years=1)

# %%
daily_sales
# Out:
#             recordno  countbasedtotal  dollarcountbasedtotal  \
# saledate
# 2019-11-05         2                4                 120.00
# 2019-11-06         2                2                  57.00
# 2019-11-07         0                0                   0.00
# 2019-11-08         0                0                   0.00
# 2019-11-09         0                0                   0.00
# ...              ...              ...                    ...
# 2024-11-08    756711            69164             1665549.47
# 2024-11-09    711541            78647             1874344.36
# 2024-11-10    757776           101058             2398632.54
# 2024-11-11    714479            90972             2154327.15
# 2024-11-12    760786            63920             1570499.56
#
#             weightbasedtotal  dollarweightbasedtotal   quantity  totalprice
# saledate
# 2019-11-05              0.00                    0.00       4.00      120.00
# 2019-11-06              0.00                    0.00       2.00       57.00
# 2019-11-07              0.00                    0.00       0.00        0.00
# 2019-11-08              0.00                    0.00       0.00        0.00
# 2019-11-09              0.00                    0.00       0.00        0.00
# ...                      ...                     ...        ...         ...
# 2024-11-08         451068.23              2741836.29  520451.33  4407385.76
# 2024-11-09         507681.95              3146880.11  586328.95  5021224.47
# 2024-11-10         642651.18              3934261.18  743709.18  6332893.72
# 2024-11-11         543568.90              3338630.93  634540.90  5492958.08
# 2024-11-12         424694.71              2581819.29  488822.81  4152318.85
#
# [1834 rows x 7 columns]
